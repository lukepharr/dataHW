# %%
import seaborn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#manually edited name of the second Port James to "Port James (2)" to avoid merge errors
city_df=pd.read_csv("city_data.csv")
ride_df=pd.read_csv("ride_data.csv")
city_df['city'][100]='Port James (2)'
# Out:
# /Users/Luke/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df=pd.merge(ride_df,city_df,how='inner')

# %%
fare_mean_df=df.groupby(df['city']).mean()['fare']

# %%
total_rides_df=df.groupby(df['city']).count()['ride_id']

# %%
total_drivers_df=city_df[['city','driver_count']]

# %%
city_type=type_df=city_df[['city','type']]

# %%
total_rides_df=total_rides_df.reset_index()
fare_mean_df=fare_mean_df.reset_index()

# %%
merge_df=pd.merge(total_rides_df,fare_mean_df,on='city').rename(columns={'ride_id':'rides'})
merge_df=pd.merge(merge_df,city_type,on='city')
merge_df=pd.merge(merge_df,total_drivers_df,on='city')
merge_df
# Out:
#                      city  rides       fare      type  driver_count
# 0            Alvarezhaven     31  23.928710     Urban            21
# 1              Alyssaberg     26  20.609615     Urban            67
# 2              Anitamouth      9  37.315556  Suburban            16
# 3            Antoniomouth     22  23.625000     Urban            21
# 4            Aprilchester     19  21.981579     Urban            49
# 5              Arnoldview     31  25.106452     Urban            41
# 6            Campbellport     15  33.711333  Suburban            26
# 7             Carrollbury     10  36.606000  Suburban             4
# 8             Carrollfort     29  25.395517     Urban            55
# 9               Clarkstad     12  31.051667  Suburban            21
# 10            Conwaymouth     11  34.591818  Suburban            18
# 11              Davidtown     21  22.978095     Urban            73
# 12              Davistown     25  21.497200     Urban            25
# 13        East Cherylfurt     13  31.416154  Suburban             9
# 14           East Douglas     22  26.169091     Urban            12
# 15              East Erin     28  24.478214     Urban            43
# 16   East Jenniferchester     19  32.599474  Suburban            22
# 17            East Leslie     11  33.660909     Rural             9
# 18           East Stephen     10  39.053000     Rural             6
# 19          East Troybury      7  33.244286     Rural             3
# 20            Edwardsbury     27  26.876667     Urban            11
# 21               Erikport      8  30.043750     Rural             3
# 22               Eriktown     19  25.478947     Urban            15
# 23             Floresberg     10  32.310000  Suburban             7
# 24             Fosterside     24  23.034583     Urban            69
# 25         Hernandezshire      9  32.002222     Rural            10
# 26              Horneland      4  21.482500     Rural             8
# 27            Jacksonfort      6  32.006667     Rural             6
# 28              Jacobfort     31  24.779355     Urban            52
# 29              Jasonfort     12  27.831667  Suburban            25
# ..                    ...    ...        ...       ...           ...
# 95              South Roy     22  26.031364     Urban            35
# 96   South Shannonborough     15  26.516667  Suburban             9
# 97            Spencertown     26  23.681154     Urban            68
# 98            Stevensport      5  31.948000     Rural             6
# 99            Stewartview     30  21.614000     Urban            49
# 100           Swansonbury     34  27.464706     Urban            64
# 101            Thomastown     24  30.308333  Suburban             1
# 102            Tiffanyton     13  28.510000  Suburban            21
# 103           Torresshire     26  24.207308     Urban            70
# 104           Travisville     23  27.220870     Urban            37
# 105            Vickimouth     15  21.474667     Urban            13
# 106           Webstertown     16  29.721250  Suburban            26
# 107           West Alexis     20  19.523000     Urban            47
# 108           West Brandy     30  24.157667     Urban            12
# 109      West Brittanyton     24  25.436250     Urban             9
# 110         West Dawnfurt     29  22.330345     Urban            34
# 111             West Evan     12  27.013333  Suburban             4
# 112      West Jefferyfurt     21  21.072857     Urban            65
# 113        West Kevintown      7  21.528571     Rural             5
# 114            West Oscar     29  24.280000     Urban            11
# 115    West Pamelaborough     14  33.799286  Suburban            27
# 116         West Paulport     17  33.278235  Suburban             5
# 117            West Peter     31  24.875484     Urban            61
# 118      West Sydneyhaven     18  22.368333     Urban            70
# 119             West Tony     19  29.609474  Suburban            17
# 120        Williamchester     11  34.278182  Suburban            26
# 121          Williamshire     31  26.990323     Urban            70
# 122           Wiseborough     19  22.676842     Urban            55
# 123           Yolandafurt     20  27.205500     Urban             7
# 124        Zimmermanmouth     24  28.301667     Urban            45
#
# [125 rows x 5 columns]

# %%
merge_df_U=merge_df.loc[merge_df['type']=='Urban',:]
merge_df_S=merge_df.loc[merge_df['type']=='Suburban',:]
merge_df_R=merge_df.loc[merge_df['type']=='Rural',:]

# %%
plt.hold(True)
plt.scatter(x=merge_df_U['driver_count'],y=merge_df_U['rides'],s=merge_df_U['fare']*2,color='gold')
plt.scatter(x=merge_df_S['driver_count'],y=merge_df_S['rides'],s=merge_df_S['fare']*2, color='coral')
plt.scatter(x=merge_df_R['driver_count'],y=merge_df_R['rides'],s=merge_df_R['fare']*2, color='lightblue')

plt.show()
# Out:
# /Users/Luke/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   """Entry point for launching an IPython kernel.
# /Users/Luke/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# /Users/Luke/anaconda/lib/python3.6/site-packages/matplotlib/rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")
